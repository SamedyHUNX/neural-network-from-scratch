# %% [markdown]
# ## ReLU Activation Function

# %%
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]

output = []
for i in inputs:
    if i > 0:
        output.append(i)
    else:
        output.append(0)

print(output)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %% [markdown]
# ## Simpler ReLU

# %%
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]

output = []
for i in inputs:
    output.append(max(0, i))

print(output)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %%
class Activation_ReLU:
    def forward(self, inputs):
        self.output = np.maximum(0, inputs)

# %% [markdown]
# ## Softmax Function

# %%
layer_outputs = [4.8, 1.21, 2.385]

E = 2.7182

exp_values = []
for output in layer_outputs:
    exp_values.append(E ** output)

print('exponentiated values:')
print(exp_values)
# Out:
# exponentiated values:
# [121.49286094351093, 3.3533625034658474, 10.858283047454606]

# %% [markdown]
# ![Screenshot 2025-05-18 at 11.38.10 in the morning.png](attachment:7c32ecc9-ad91-428b-b016-3024415d15b5.png)

# %%
# Now normalize values
norm_base = sum(exp_values) # We sum all values
norm_values = []

for value in exp_values:
    norm_values.append(value / norm_base)

print('Normalized exponentiated values: ')
print(norm_values)

print('Sum of normalized values: ', sum(norm_values))
# Out:
# Normalized exponentiated values:
# [0.8952750655225764, 0.02471076746153196, 0.0800141670158918]
# Sum of normalized values:  1.0000000000000002

# %%
import numpy as np

# %%
layer_outputs = [4.8, 1.21, 2.385]
# For each value in a vector, calculate the exponential value
exp_values = np.exp(layer_outputs)
print('exponentiated values:')
print(exp_values)
# Now normalize values
norm_values = exp_values / np.sum(exp_values)
print('normalized exponentiated values:')
print(norm_values)
print('sum of normalized values:', np.sum(norm_values))
# Out:
# exponentiated values:
# [121.51041752   3.35348465  10.85906266]
# normalized exponentiated values:
# [0.89528266 0.02470831 0.08000903]
# sum of normalized values: 0.9999999999999999

# %%
class Activation_Softmax:
    def forward(self, inputs):

        exp_values = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))

        probabilities = exp_values / np.sum(exp_values, axis=1, keepdims=True)

        self.output = probabilities

# %%
softmax = Activation_Softmax()

softmax.
